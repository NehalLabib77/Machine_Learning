# %%
import numpy as np

# %%
list_num = [7, 23, 4, 19, 42, 11, 35, 2, 28, 16,
9, 31, 14, 6, 25, 38, 1, 20, 33, 12]

minimum,Q1,median,Q3,maximum = np.quantile(list_num,[0,0.25,0.50,0.75,1.0])

# %%
minimum,Q1,median,Q3,maximum
# Out:
# (np.float64(1.0),
#  np.float64(8.5),
#  np.float64(17.5),
#  np.float64(28.75),
#  np.float64(42.0))

# %%
# For outlier we find IQR -000-
