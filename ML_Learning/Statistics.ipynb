# %% [markdown]
# https://www.notion.so/Statistics-2e55068948828021b0c1c06dce78b68c?source=copy_link

# %% [markdown]
# https://www.notion.so/Probability-Distribution-2e65068948828062afece2b8c808d40d?source=copy_link
