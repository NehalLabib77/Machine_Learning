# %% [markdown]
# # Lesson 1.2: Python Basics
# ## Topics Covered:
# - Syntax and Semantics
# - Variables and Data Types
# - Basic Operators (Arithmetic, Comparison, Logical)

# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input and prints it.

# %%
x = input("Enter something: ")
print(x)
# Out:
# 5
# 5

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
x = 2 
if x == 0:
    print("zero")
elif x > 0:
    print("positive")
elif x<0:
    print("Negative")
# Out:
# positive

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
x = 10
y = 2
z = 11

if x >= y and x >= z:
    print("x is bigger")
elif y >= x and y >= z:
    print("y is bigger")
else:
    print("z is bigger")

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %%
n = 5
factorial = 1

for i in range(1, n + 1):
    factorial = factorial * i

print(f"Factorial of {n} is {factorial}")
# Out:
# Factorial of 5 is 120

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
name = "Noor Nehal Tanzim"
age = 22
height = 5.8 
is_student = True

print(name)
print(type(name))

print(age)
print(type(age))

print(height)
print(type(height))

print(is_student)
print(type(is_student))
# Out:
# Noor Nehal Tanzim
# <class 'str'>
# 22
# <class 'int'>
# 5.8
# <class 'float'>
# True
# <class 'bool'>

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %%
x = 20  
y = 10
(x,y) = (y,x)
print(x,y)
# Out:
# 10 20

# %% [markdown]
# **Question 8:** Write a Python program to convert Celsius to Fahrenheit.

# %%
c = 10
f = ((c * 9) / 5) + 32
print(f)
# Out:
# 50.0

# %% [markdown]
# **Question 9:** Write a Python program to concatenate two strings.

# %%
a = "hello"
b = "world"

c = a +" "+ b
print(c)
# Out:
# hello world

# %% [markdown]
# **Question 10:** Write a Python program to check if a variable is of a specific data type.

# %%
# Two way of checking if a data type is of specific type 

a = 10
if type(a) == int:
    print("It is Int ")

if isinstance(a, int):
    print("Int")
# Out:
# It is Int
# Int

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 11:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
a = 15
b = 4

print('sum = ', a + b)
print('difference = ', a - b)
print('product = ', a * b)
print('true division = ', a / b)
print('floor division = ', a // b) # Result nearest whole integer 
print('remainder = ', a % b)
print('power (a**b) :', a ** b)
# Out:
# sum =  19
# difference =  11
# product =  60
# true division =  3.75
# floor division =  3
# remainder =  3
# power (a**b) : 50625

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
a = 10
b = 20

if (a == b):
    print("Equal")
if (a != b):
    print("Not Equal")
if (a > b):
    print("A is bigger")
if (a < b):
    print("A is less than")
# Out:
# Not Equal
# A is less than

# %% [markdown]
# **Question 13:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
x = 10 


if x > 5 and x < 11:
    print("X is between 5 and 10")
if x > 5 or x < 10:
    print("X is either grater than 5 or less than 10")
if not x > 10:
    print("X is not grater than 10")
# Out:
# X is between 5 and 10
# X is either grater than 5 or less than 10
# X is not grater than 10

# %% [markdown]
# **Question 14:** Write a Python program to calculate the square of a number.

# %%
x = 20
y = 2
print(f"Square is {x**y}")
# Out:
# square is 400

# %% [markdown]
# **Question 15:** Write a Python program to check if a number is even or odd.

# %%
x = 10
if(x % 2 == 0):
    print("Even")
else:
    print("Odd")
# Out:
# Even

# %% [markdown]
# **Question 16:** Write a Python program to find the sum of the first n natural numbers.

# %%
n = int(input())
x = 0
for i in range (1, n+1):
    x = x + i
print(x)
# Out:
# 55

# %% [markdown]
# **Question 17:** Write a Python program to check if a year is a leap year.

# %%
x = int(input())

if (x % 400 == 0) or ( x % 4 == 0 and x % 100 != 0 ):
    print("Leap year")
else :
    print("No leap year")
# Out:
# No leap year

# %% [markdown]
# **Question 18:** Write a Python program to reverse a string.

# %%
N = "Hello"
rev = N[::-1]
print(rev)
# Out:
# olleH

# %% [markdown]
# **Question 19:** Write a Python program to check if a string is a palindrome.

# %%
N = "121"
rev = N[::-1]

if (N == rev):
    print("Palindrome")
else:
    print("Not a palindrome")
# Out:
# Palindrome

# %% [markdown]
# **Question 20:** Write a Python program to sort a list of numbers in ascending order.

# %%
A = [10,4,3,5,7,3,8]
A.sort()
print(A)
# Out:
# [3, 3, 4, 5, 7, 8, 10]
