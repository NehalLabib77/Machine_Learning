# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# Importing the dataset
from sklearn.datasets import make_classification

# %%
X,y = make_classification(n_samples = 1000, n_features = 2, n_classes = 2,n_redundant = 0
                          , n_clusters_per_class=1)

# %%
X
# Out:
# array([[ 0.44379368,  0.79663995],
#        [-1.01415322,  0.6006122 ],
#        [ 0.00689841,  0.7037774 ],
#        ...,
#        [-0.61425146,  1.00124389],
#        [ 0.74506329,  0.85137601],
#        [ 0.11595513,  1.09402225]], shape=(1000, 2))

# %%
pd.DataFrame(X)[0]
# Out:
# 0      0.443794
# 1     -1.014153
# 2      0.006898
# 3     -0.817380
# 4      1.750410
#          ...
# 995    0.797786
# 996   -1.136366
# 997   -0.614251
# 998    0.745063
# 999    0.115955
# Name: 0, Length: 1000, dtype: float64

# %%
df = pd.DataFrame(X, columns=["feature_1", "feature_2"])
df["target"] = y

sns.scatterplot(data=df, x="feature_1", y="feature_2", hue="target")
plt.title("Synthetic Classification Data")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 sns.scatterplot(pd.DataFrame(X)[0],pd.DataFrame(X)[1], hue= pd.DataFrame(y)[0])
#
# TypeError: scatterplot() takes from 0 to 1 positional arguments but 2 positional arguments (and 1 keyword-only argument) were given
