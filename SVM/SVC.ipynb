# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# Importing the dataset
from sklearn.datasets import make_classification

# %%
X,y = make_classification(n_samples = 1000, n_features = 2, n_classes = 2,n_redundant = 0
                          , n_clusters_per_class=2)

# %%
X
# Out:
# array([[-1.18863757, -1.71400666],
#        [ 0.06831312,  1.0862074 ],
#        [ 0.92582253, -0.76767673],
#        ...,
#        [ 0.47376816,  0.62571028],
#        [ 0.64073527,  0.68915635],
#        [ 0.30144185,  1.60506148]], shape=(1000, 2))

# %%
pd.DataFrame(X)[0]
# Out:
# 0     -1.188638
# 1      0.068313
# 2      0.925823
# 3     -1.527851
# 4      1.398881
#          ...
# 995    0.804938
# 996   -0.639306
# 997    0.473768
# 998    0.640735
# 999    0.301442
# Name: 0, Length: 1000, dtype: float64

# %%
df = pd.DataFrame(X, columns=["feature_1", "feature_2"])
df["target"] = y

sns.scatterplot(data=df, x="feature_1", y="feature_2", hue="target")
plt.title("Synthetic Classification Data")
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = .30,random_state = 42)

# %%
from sklearn.svm import SVC

# %%
svc = SVC(kernel= 'linear')
svc.fit(X_train,y_train)
y_pred = svc.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.89      0.89       155
#            1       0.88      0.88      0.88       145
#
#     accuracy                           0.88       300
#    macro avg       0.88      0.88      0.88       300
# weighted avg       0.88      0.88      0.88       300

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[138  17]
#  [ 18 127]]
